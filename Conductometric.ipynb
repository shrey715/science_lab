# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn

# %%
x = [0]
for i in range(5):
    x.append(x[len(x)-1]+8)
for i in range(10):
    x.append(x[len(x)-1]+4)
for i in range(37):
    x.append(x[len(x)-1]+2)
for i in range(5):
    x.append(x[len(x)-1]+4)

# %%
plotx = np.array(x)/10
plotx
# Out:
# array([ 0. ,  0.8,  1.6,  2.4,  3.2,  4. ,  4.4,  4.8,  5.2,  5.6,  6. ,
#         6.4,  6.8,  7.2,  7.6,  8. ,  8.2,  8.4,  8.6,  8.8,  9. ,  9.2,
#         9.4,  9.6,  9.8, 10. , 10.2, 10.4, 10.6, 10.8, 11. , 11.2, 11.4,
#        11.6, 11.8, 12. , 12.2, 12.4, 12.6, 12.8, 13. , 13.2, 13.4, 13.6,
#        13.8, 14. , 14.2, 14.4, 14.6, 14.8, 15. , 15.2, 15.4, 15.8, 16.2,
#        16.6, 17. , 17.4])

# %%
ploty = np.array([141,135,128,120,114,109,105,101,98,95,91,88,85,83,80,77,76,74,73,71,70,69,67,66,64,62,61,60,58,57,55,54,53,53,51,49,48,46,45,43,43,41,40,39,37,36,35,34,36,36,37,38,39,40,41,43,44,45])

# %%
ploty
# Out:
# array([141, 135, 128, 120, 114, 109, 105, 101,  98,  95,  91,  88,  85,
#         83,  80,  77,  76,  74,  73,  71,  70,  69,  67,  66,  64,  62,
#         61,  60,  58,  57,  55,  54,  53,  53,  51,  49,  48,  46,  45,
#         43,  43,  41,  40,  39,  37,  36,  35,  34,  36,  36,  37,  38,
#         39,  40,  41,  43,  44,  45])

# %%
plt.figure(figsize = (11,8))
plt.plot(plotx,ploty,'o-',c = 'r',)
plt.title(label = "Conductance vs Volume of NaOH")
plt.xlabel("Volume of NaOH(ml)")
plt.ylabel("Conductance(S)")
plt.grid(True,color='g')
plt.savefig("con1.png")

# %%
x = [0]
for i in range(10):
    x.append(x[len(x)-1]+8)
for i in range(10):
    x.append(x[len(x)-1]+4)
for i in range(19):
    x.append(x[len(x)-1]+2)
for i in range(5):
    x.append(x[len(x)-1]+4)

# %%
plotx2 = np.array(x)/10
ploty2 = np.array([146,138,130,123,115,110,103,97,89,84,78,76,73,70,67,65,61,57,54,53,51,50,48,46,45,44,43,41,41,39,38,37,35,34,34,35,36,37,37,38,39,40,42,43,44])
print(len(plotx))
print(len(ploty))
# Out:
# 58
# 58

# %%
plt.figure(figsize = (11,8))
plt.plot(plotx,ploty,'o-',c = 'r',label = 'without phenolphthalein')
plt.plot(plotx2,ploty2,'o-', c= 'b',label = 'with phenolphthalein')
plt.title(label = "Conductance vs Volume of NaOH")
plt.xlabel("Volume of NaOH(ml)")
plt.ylabel("Conductance(S)")
plt.grid(True,color='g')
plt.legend()
plt.savefig("con3.png")
